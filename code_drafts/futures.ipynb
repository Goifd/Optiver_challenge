# %% [markdown]
# - trade futures
# - retreat strategy, each clip higher credit to avoid position
#     - people usually get stuck in their positions
#     - markets get extremely liquid
# - instead of mid point use bid and ask of underlying spread
# - Paper:
#     - price based on latest trading price
#     - adjust ask/bid spread based on market volatility
#     - trend follow strategy driven by order imbalance

# %%
import datetime as dt
import time
import logging

from optibook.synchronous_client import Exchange
from optibook.common_types import InstrumentType, OptionKind

from math import floor, ceil, exp
from black_scholes import call_value, put_value, call_delta, put_delta
from libs import calculate_current_time_to_date

exchange = Exchange()
exchange.connect()

logging.getLogger('client').setLevel('ERROR')

# %%
def trade_would_breach_position_limit(instrument_id, volume, side, position_limit=100):
    positions = exchange.get_positions()
    position_instrument = positions[instrument_id]

    if side == 'bid':
        return position_instrument + volume > position_limit
    elif side == 'ask':
        return position_instrument - volume < -position_limit
    else:
        raise Exception(f'''Invalid side provided: {side}, expecting 'bid' or 'ask'.''')

# %%
def round_down_to_tick(price, tick_size):
    """
    Rounds a price down to the nearest tick, e.g. if the tick size is 0.10, a price of 0.97 will get rounded to 0.90.
    """
    return floor(price / tick_size) * tick_size


def round_up_to_tick(price, tick_size):
    """
    Rounds a price up to the nearest tick, e.g. if the tick size is 0.10, a price of 1.34 will get rounded to 1.40.
    """
    return ceil(price / tick_size) * tick_size

# %%
def load_futures_for_underlying(underlying_group_id):

    all_instruments = exchange.get_instruments()

    futures = {instrument_id: instrument
               for instrument_id, instrument in all_instruments.items()
               if (instrument.instrument_type == InstrumentType.INDEX_FUTURE or instrument.instrument_type == InstrumentType.STOCK_FUTURE)
               and instrument.instrument_group == underlying_group_id}
    
    return futures

# %%
def load_instruments_for_underlying(underlying_stock_id):
    all_instruments = exchange.get_instruments()
    stock = all_instruments[underlying_stock_id]
    options = {instrument_id: instrument
               for instrument_id, instrument in all_instruments.items()
               if instrument.instrument_type == InstrumentType.STOCK_OPTION
               and instrument.base_instrument_id == underlying_stock_id}
    return options

# %%
def load_instruments_for_OB5X():
    all_instruments = exchange.get_instruments()
    filtered_dict = {key: value for key, value in all_instruments.items() if value.instrument_group == 'OB5X' and value.instrument_type == InstrumentType.INDEX_OPTION}
    return filtered_dict

# %%
def get_midpoint_value(instrument_id):
    """
    This function calculates the current midpoint of the order book supplied by the exchange for the instrument
    specified by <instrument_id>, returning None if either side or both sides do not have any orders available.
    """
    order_book = exchange.get_last_price_book(instrument_id=instrument_id)

    # If the instrument doesn't have prices at all or on either side, we cannot calculate a midpoint and return None
    if not (order_book and order_book.bids and order_book.asks):
        return None
    else:
        midpoint = (order_book.bids[0].price + order_book.asks[0].price) / 2.0
        return midpoint

# %%
def get_OB5X_value(side):
    """
    Calculates the value of the OB5X index
    """
    
    val = 0 
    if(side=='ask'):
        if(len(exchange.get_last_price_book('NVDA').asks)==0 or len(exchange.get_last_price_book('ING').asks)==0 or len(exchange.get_last_price_book('SAN').asks)==0 or len(exchange.get_last_price_book('PFE').asks)==0 or len(exchange.get_last_price_book('CSCO').asks) == 0):
            return None
        NVDA = exchange.get_last_price_book(instrument_id='NVDA').asks[0].price
        ING = exchange.get_last_price_book(instrument_id='ING').asks[0].price
        SAN = exchange.get_last_price_book(instrument_id='SAN').asks[0].price
        PFE = exchange.get_last_price_book(instrument_id='PFE').asks[0].price
        CSCO = exchange.get_last_price_book(instrument_id='CSCO').asks[0].price

        val = (908.06*NVDA + 129.24*ING + 124.78*SAN + 2245.39*PFE + 953.21*CSCO)/1000
    else:
        if(len(exchange.get_last_price_book('NVDA').bids)==0 or len(exchange.get_last_price_book('ING').bids)==0 or len(exchange.get_last_price_book('SAN').bids)==0 or len(exchange.get_last_price_book('PFE').bids)==0 or len(exchange.get_last_price_book('CSCO').bids) == 0):
            return None
        NVDA = exchange.get_last_price_book(instrument_id='NVDA').bids[0].price
        ING = exchange.get_last_price_book(instrument_id='ING').bids[0].price
        SAN = exchange.get_last_price_book(instrument_id='SAN').bids[0].price
        PFE = exchange.get_last_price_book(instrument_id='PFE').bids[0].price
        CSCO = exchange.get_last_price_book(instrument_id='CSCO').bids[0].price

        val = (908.06*NVDA + 129.24*ING + 124.78*SAN + 2245.39*PFE + 953.21*CSCO)/1000
    

    return val

# %%
def ETF_val(index_val):
    C = 2.5
    M = 0.25
    return C + M*index_val

# %%
def calculate_theoretical_future_value(underlying_value, expiry,  interest_rate=0.03):
    """
    This function calculates the current fair future value with: F = X exp(rt)

    expiry: dt.date          -  Expiry date of the future -  third Friday of current month, at 12:00 UTC
    underlying_value:        -  value of the underlying stock/index
    interest_rate:           -  interest rate of future
    """
    time_to_expiry = calculate_current_time_to_date(expiry)

    future_value = underlying_value*exp(interest_rate*time_to_expiry)

    return future_value

# %%
def calculate_theoretical_option_value(expiry, strike, option_kind, stock_value, interest_rate, volatility):
    """
    This function calculates the current fair call or put value based on Black & Scholes assumptions.

    expiry: dt.date          -  Expiry date of the option
    strike: float            -  Strike price of the option
    option_kind: OptionKind  -  Type of the option
    stock_value:             -  Assumed stock value when calculating the Black-Scholes value
    interest_rate:           -  Assumed interest rate when calculating the Black-Scholes value
    volatility:              -  Assumed volatility of when calculating the Black-Scholes value
    """
    time_to_expiry = calculate_current_time_to_date(expiry)


    if option_kind == OptionKind.CALL:
        option_value = call_value(S=stock_value, K=strike, T=time_to_expiry, r=interest_rate, sigma=volatility)
    elif option_kind == OptionKind.PUT:
        option_value = put_value(S=stock_value, K=strike, T=time_to_expiry, r=interest_rate, sigma=volatility)

    return option_value

# %%
def update_quotes(instrument_id, theoretical_price, credit, volume, position_limit, tick_size):
    """
    This function updates the quotes specified by <option_id>. We take the following actions in sequence:
        - pull (remove) any current oustanding orders
        - add credit to theoretical price and round to nearest tick size to create a set of bid/ask quotes
        - calculate max volumes to insert as to not pass the position_limit
        - reinsert limit orders on those levels

    Arguments:
        option_id: str           -  Exchange Instrument ID of the option to trade
        theoretical_price: float -  Price to quote around
        credit: float            -  Difference to subtract from/add to theoretical price to come to final bid/ask price
        volume:                  -  Volume (# lots) of the inserted orders (given they do not breach position limits)
        position_limit: int      -  Position limit (long/short) to avoid crossing
        tick_size: float         -  Tick size of the quoted instrument
    """

    # Print any new trades
    trades = exchange.poll_new_trades(instrument_id=instrument_id)

    # Pull (remove) all existing outstanding orders
    orders = exchange.get_outstanding_orders(instrument_id=instrument_id)
    for order_id, order in orders.items():
        exchange.delete_order(instrument_id=instrument_id, order_id=order_id)

    # Calculate bid and ask price
    bid_price = round_down_to_tick(theoretical_price - credit, tick_size)
    ask_price = round_up_to_tick(theoretical_price + credit, tick_size)

    # Calculate bid and ask volumes, taking into account the provided position_limit
    position = exchange.get_positions()[instrument_id]

    max_volume_to_buy = position_limit - position
    max_volume_to_sell = position_limit + position

    bid_volume = min(volume, max_volume_to_buy)
    ask_volume = min(volume, max_volume_to_sell)

    # Insert new limit orders
    if bid_volume > 0:
        exchange.insert_order(
            instrument_id=instrument_id,
            price=bid_price,
            volume=bid_volume,
            side='bid',
            order_type='limit',
        )
        print(f'- Inserting bid limit order in {instrument_id} for {bid_volume} @ {bid_price:8.2f}.')
    if ask_volume > 0:
        exchange.insert_order(
            instrument_id=instrument_id,
            price=ask_price,
            volume=ask_volume,
            side='ask',
            order_type='limit',
        )
        print(f'- Inserting ask limit order in {instrument_id} for {ask_volume} @ {ask_price:8.2f}.')

# %%
def calculate_option_delta(expiry_date, strike, option_kind, stock_value, interest_rate, volatility):
    """
    This function calculates the current option delta based on Black & Scholes assumptions.

    expiry_date: dt.date     -  Expiry date of the option
    strike: float            -  Strike price of the option
    option_kind: OptionKind  -  Type of the option
    stock_value:             -  Assumed stock value when calculating the Black-Scholes value
    interest_rate:           -  Assumed interest rate when calculating the Black-Scholes value
    volatility:              -  Assumed volatility of when calculating the Black-Scholes value
    """
    time_to_expiry = calculate_current_time_to_date(expiry_date)

    if option_kind == OptionKind.CALL:
        option_delta = call_delta(S=stock_value, K=strike, T=time_to_expiry, r=interest_rate, sigma=volatility)
    elif option_kind == OptionKind.PUT:
        option_delta = put_delta(S=stock_value, K=strike, T=time_to_expiry, r=interest_rate, sigma=volatility)
    else:
        raise Exception(f"""Got unexpected value for option_kind argument, should be OptionKind.CALL or OptionKind.PUT but was {option_kind}.""")

    return option_delta

# %%
def hedge_delta_position(stock_id, stock_value, futures=None, options=None, dual=None):
    """
    This function (once finished) hedges the outstanding delta position by trading in the stock.

    That is:
        - It calculates how sensitive the total position value is to changes in the underlying by summing up all
          individual delta component.
        - And then trades stocks which have the opposite exposure, to remain, roughly, flat delta exposure

    Arguments:
        stock_id: str         -  Exchange Instrument ID of the stock to hedge with
        options: List[dict]   -  List of options with details to calculate and sum up delta positions for
        stock_value: float    -  The stock value to assume when making delta calculations using Black-Scholes
    """

    # A2: Calculate the delta position here
    positions = exchange.get_positions()

    total_delta = 0

    # hedge options
    if options != None:
        for option_id, option in options.items():
            position = positions[option_id]
            current_delta = calculate_option_delta(option.expiry, option.strike, option.option_kind, stock_value, 0.03, 3.0)
            total_delta += current_delta * position
            print(f"- The current position in option {option_id} is {position}.")

    # hedge futures
    if futures != None:
        for future_id, future in futures.items():
            position = positions[future_id]
            # current_delta = calculate_future_delta()
            total_delta += position

    # hedge dual 
    if dual != None:
        total_delta += positions[dual]


    stock_position = positions[stock_id]

    stock_order_book = exchange.get_last_price_book(stock_id)

    # if empty hedge order book escape function
    if not (stock_order_book and stock_order_book.bids and stock_order_book.asks):
            return

    # compare position in underlying stock to necessary position for hedging and determine trade volume
    trade_volume = 0
    if total_delta != -stock_position:
        if total_delta < 0 and stock_position > 0:
            trade_volume = abs(stock_position + round(total_delta))
        elif total_delta > 0 and stock_position < 0:
            trade_volume = abs(stock_position + round(total_delta))
        else:
            trade_volume = abs(round(total_delta) - stock_position)
    else:
        return
    
    # instert orders into hedge instrument order book
    if trade_volume != 0:
        if stock_position < total_delta:
            if abs(stock_position) < total_delta:
                if not trade_would_breach_position_limit(stock_id, trade_volume, 'ask'):
                    exchange.insert_order(stock_id, price = 1, volume=trade_volume, side='ask', order_type='ioc')
            else:
                if not trade_would_breach_position_limit(stock_id, trade_volume, 'bid'):
                    exchange.insert_order(stock_id, price = 10000, volume=trade_volume, side='bid', order_type='ioc')
        elif total_delta < stock_position:
            if abs(total_delta) < stock_position:
                if not trade_would_breach_position_limit(stock_id, trade_volume, 'ask'):
                    exchange.insert_order(stock_id, price = 1, volume=trade_volume, side='ask', order_type='ioc')
            else:
                if not trade_would_breach_position_limit(stock_id, trade_volume, 'bid'):
                    exchange.insert_order(stock_id, price = 10000, volume=trade_volume, side='bid', order_type='ioc')
                    
    # if delta is more than we can hedge
    positions = exchange.get_positions()
    stock_position = positions[stock_id]
    print(f"stock position currently: {stock_position}")
    if stock_position != 100 and stock_position != -100:
        if total_delta >= 100:
            exchange.insert_order(stock_id, price = 1, volume = 100 + stock_position, side = 'ask', order_type = 'ioc')
        elif total_delta <= -100:
            print(f"stock position currently: {positions[stock_id]}")
            exchange.insert_order(stock_id, price = 10000, volume = 100 - stock_position, side = 'bid', order_type = 'ioc')

# %%
def trade_out_of_position():
    MIN_SELLING_PRICE = 0.10
    MAX_BUYING_PRICE = 100000.00

    positions = exchange.get_positions()
    for iid, pos in positions.items():
        if pos > 0:
            exchange.insert_order(iid, price=MIN_SELLING_PRICE, volume=pos, side='ask', order_type='ioc')
        elif pos < 0:
            exchange.insert_order(iid, price=MAX_BUYING_PRICE, volume=-pos, side='bid', order_type='ioc')    
        time.sleep(0.10)

trade_out_of_position()

# %%
def hedge_delta_position(stock_id, stock_value, futures=None, options=None, dual=None):
    """
    This function (once finished) hedges the outstanding delta position by trading in the stock.

    That is:
        - It calculates how sensitive the total position value is to changes in the underlying by summing up all
          individual delta component.
        - And then trades stocks which have the opposite exposure, to remain, roughly, flat delta exposure

    Arguments:
        stock_id: str         -  Exchange Instrument ID of the stock to hedge with
        options: List[dict]   -  List of options with details to calculate and sum up delta positions for
        stock_value: float    -  The stock value to assume when making delta calculations using Black-Scholes
    """

    # A2: Calculate the delta position here
    positions = exchange.get_positions()

    total_delta = 0

    # hedge options
    if options != None:
        if stock_id == 'OB5X_ETF':
            for option_id, option in options.items():
                position = positions[option_id]
                current_delta = calculate_option_delta(option.expiry, option.strike, option.option_kind, stock_value, 0.03, 3.0)
                current_delta = current_delta / 0.25
                total_delta += current_delta * position
                print(f"- The current position in option {option_id} is {position}.")
        else:
            for option_id, option in options.items():
                position = positions[option_id]
                current_delta = calculate_option_delta(option.expiry, option.strike, option.option_kind, stock_value, 0.03, 3.0)
                total_delta += current_delta * position
                print(f"- The current position in option {option_id} is {position}.")

    # hedge futures
    if futures != None:
        if stock_id == 'OB5X_ETF':
            for future_id, future in futures.items():
                position = positions[future_id]
                current_delta = exp(0.03*calculate_current_time_to_date(future.expiry))/0.25
                total_delta += position * current_delta
        elif stock_id == 'NVDA':
            for future_id, future in futures.items():
                position = positions[future_id]
                total_delta += current_delta

    # hedge dual 
    if dual != None:
        total_delta += positions[dual]


    stock_position = positions[stock_id]

    stock_order_book = exchange.get_last_price_book(stock_id)

    # if empty hedge order book escape function
    if not (stock_order_book and stock_order_book.bids and stock_order_book.asks):
            return

    # compare position in underlying stock to necessary position for hedging and determine trade volume
    trade_volume = 0
    if total_delta != -stock_position:
        if total_delta < 0 and stock_position > 0:
            trade_volume = abs(stock_position + round(total_delta))
        elif total_delta > 0 and stock_position < 0:
            trade_volume = abs(stock_position + round(total_delta))
        else:
            trade_volume = abs(round(total_delta) - stock_position)
    else:
        return
    
    # instert orders into hedge instrument order book
    if trade_volume != 0:
        if stock_position < total_delta:
            if abs(stock_position) < total_delta:
                if not trade_would_breach_position_limit(stock_id, trade_volume, 'ask'):
                    exchange.insert_order(stock_id, price = 1, volume=trade_volume, side='ask', order_type='ioc')
            else:
                if not trade_would_breach_position_limit(stock_id, trade_volume, 'bid'):
                    exchange.insert_order(stock_id, price = 10000, volume=trade_volume, side='bid', order_type='ioc')
        elif total_delta < stock_position:
            if abs(total_delta) < stock_position:
                if not trade_would_breach_position_limit(stock_id, trade_volume, 'ask'):
                    exchange.insert_order(stock_id, price = 1, volume=trade_volume, side='ask', order_type='ioc')
            else:
                if not trade_would_breach_position_limit(stock_id, trade_volume, 'bid'):
                    exchange.insert_order(stock_id, price = 10000, volume=trade_volume, side='bid', order_type='ioc')
                    
    # if delta is more than we can hedge
    positions = exchange.get_positions()
    stock_position = positions[stock_id]
    print(f"stock position currently: {stock_position}")
    if stock_position != 100 and stock_position != -100:
        if total_delta >= 100:
            exchange.insert_order(stock_id, price = 1, volume = 100 + stock_position, side = 'ask', order_type = 'ioc')
        elif total_delta <= -100:
            print(f"stock position currently: {positions[stock_id]}")
            exchange.insert_order(stock_id, price = 10000, volume = 100 - stock_position, side = 'bid', order_type = 'ioc')

# %%
def credit_calc (instrument_id, volume_steps, increment):
    position = exchange.get_positions()
    instrument_position = position[instrument_id]
    credit = -round(instrument_position / volume_steps) * increment
    return credit

# %%
NVDA_ID = "NVDA"
NVDA_DUAL = "NVDA_DUAL"
OB5X_ID = "OB5X"
OB5X_ETF = 'OB5X_ETF'

flag = True
while True:
    OB5X_value_ask = get_OB5X_value('ask')
    OB5X_value_bid = get_OB5X_value('bid')
    options = load_instruments_for_OB5X()
    order_book = exchange.get_last_price_book(OB5X_ETF)

    if (OB5X_value_ask is None or OB5X_value_bid is None):
        continue

    for option_id, option in options.items():
        if (len(order_book.bids) == 0 or len(order_book.asks) == 0):
            continue

        theoretical_value_bid = calculate_theoretical_option_value(expiry = option.expiry,
                                                                   strike = option.strike,
                                                                   option_kind = option.option_kind,
                                                                   stock_value = OB5X_value_bid,
                                                                   interest_rate = 0.03,
                                                                   volatility = 1.5)
        position = exchange.get_last_price_book(option_id)

        option_price = position.bids[0].price
        option_price1 = position.asks[0].price
        
        
        
        print(f"option id: {option_id}")
        print(f"theoretical bid: {theoretical_value_bid}")
        print(f"best bid: {option_price}")
        
        theoretical_value_ask = calculate_theoretical_option_value(expiry = option.expiry,
                                                                   strike = option.strike,
                                                                   option_kind = option.option_kind,
                                                                   stock_value = OB5X_value_ask,
                                                                   interest_rate = 0.03,
                                                                   volatility = 1.5)
        print(f"theoretical ask: {theoretical_value_ask}")
        print(f"best ask: {option_price1}")

        
        if option.option_kind == OptionKind.CALL:
            price_diff = (theoretical_value_ask - theoretical_value_bid)
            mid_price = theoretical_value_bid + price_diff/2

        elif option.option_kind == OptionKind.PUT:
            price_diff = (theoretical_value_bid - theoretical_value_ask)
            mid_price = theoretical_value_ask + price_diff/2

        update_quotes(instrument_id=option_id,
                        theoretical_price = mid_price + credit_calc(option_id, 10, 0.1),
                        credit=price_diff/2 + 0.1,
                        volume=33,
                        position_limit=100,
                        tick_size=0.10)
        
        for i in range(1):
            hedge_delta_position(OB5X_ETF, get_midpoint_value(OB5X_ETF), futures=None, options=options, dual=None)
            time.sleep(1)
# Out:
# option id: OB5X_202406_120P
# theoretical bid: 35.92777373938556
# best bid: 35.5
# theoretical ask: 35.74795213837395
# best ask: 36.0
# - Inserting bid limit order in OB5X_202406_120P for 33 @    35.50.
# - Inserting ask limit order in OB5X_202406_120P for 33 @    36.00.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 20.
# - The current position in option OB5X_202406_080C is 4.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -48
# option id: OB5X_202406_120C
# theoretical bid: 56.63128092849935
# best bid: 56.6
# theoretical ask: 57.13746832497861
# best ask: 56.800000000000004
# - Inserting bid limit order in OB5X_202406_120C for 33 @    56.50.
# - Inserting ask limit order in OB5X_202406_120C for 33 @    57.30.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 20.
# - The current position in option OB5X_202406_080C is 4.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -48
# option id: OB5X_202406_100P
# theoretical bid: 24.57222745503132
# best bid: 24.400000000000002
# theoretical ask: 24.433838028075236
# best ask: 24.8
# - Inserting bid limit order in OB5X_202406_100P for 33 @    24.30.
# - Inserting ask limit order in OB5X_202406_100P for 33 @    24.70.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 20.
# - The current position in option OB5X_202406_080C is 4.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -48
# option id: OB5X_202406_100C
# theoretical bid: 65.05236719677546
# best bid: 64.5
# theoretical ask: 65.59998676109299
# best ask: 64.8
# - Inserting bid limit order in OB5X_202406_100C for 33 @    64.70.
# - Inserting ask limit order in OB5X_202406_100C for 33 @    65.50.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 20.
# - The current position in option OB5X_202406_080C is 4.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -48
# option id: OB5X_202406_080C
# theoretical bid: 75.19272678644947
# best bid: 75.10000000000001
# theoretical ask: 75.78242935359623
# best ask: 75.3
# - Inserting bid limit order in OB5X_202406_080C for 33 @    75.00.
# - Inserting ask limit order in OB5X_202406_080C for 33 @    75.90.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 20.
# - The current position in option OB5X_202406_080C is 4.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -48
# option id: OB5X_202406_080P
# theoretical bid: 14.935951871515606
# best bid: 14.700000000000001
# theoretical ask: 14.839645436721284
# best ask: 15.100000000000001
# - Inserting bid limit order in OB5X_202406_080P for 33 @    14.70.
# - Inserting ask limit order in OB5X_202406_080P for 33 @    15.10.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 20.
# - The current position in option OB5X_202406_080C is 4.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -48
# option id: OB5X_202406_120P
# theoretical bid: 35.87009835140152
# best bid: 35.7
# theoretical ask: 35.730998737183995
# best ask: 36.0
# - Inserting bid limit order in OB5X_202406_120P for 33 @    35.50.
# - Inserting ask limit order in OB5X_202406_120P for 33 @    35.90.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 20.
# - The current position in option OB5X_202406_080C is 4.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -48
# option id: OB5X_202406_120C
# theoretical bid: 56.79309675422683
# best bid: 56.6
# theoretical ask: 57.1853861382492
# best ask: 56.800000000000004
# - Inserting bid limit order in OB5X_202406_120C for 33 @    56.60.
# - Inserting ask limit order in OB5X_202406_120C for 33 @    57.30.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 4.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -48
# option id: OB5X_202406_100P
# theoretical bid: 24.527827474482482
# best bid: 24.5
# theoretical ask: 24.420795508423783
# best ask: 24.6
# - Inserting bid limit order in OB5X_202406_100P for 33 @    24.30.
# - Inserting ask limit order in OB5X_202406_100P for 33 @    24.70.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 4.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_100C
# theoretical bid: 65.22745861930555
# best bid: 64.7
# theoretical ask: 65.651815653348
# best ask: 64.9
# - Inserting bid limit order in OB5X_202406_100C for 33 @    64.60.
# - Inserting ask limit order in OB5X_202406_100C for 33 @    65.30.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080C
# theoretical bid: 75.381308210807
# best bid: 74.4
# theoretical ask: 75.8382287157077
# best ask: 74.9
# - Inserting bid limit order in OB5X_202406_080C for 33 @    74.80.
# - Inserting ask limit order in OB5X_202406_080C for 33 @    75.60.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080P
# theoretical bid: 14.905041762404736
# best bid: 14.8
# theoretical ask: 14.83057326729261
# best ask: 15.0
# - Inserting bid limit order in OB5X_202406_080P for 33 @    14.70.
# - Inserting ask limit order in OB5X_202406_080P for 33 @    15.10.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_120P
# theoretical bid: 36.02676535830699
# best bid: 35.7
# theoretical ask: 35.747837115684185
# best ask: 36.1
# - Inserting bid limit order in OB5X_202406_120P for 33 @    35.80.
# - Inserting ask limit order in OB5X_202406_120P for 33 @    36.40.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_120C
# theoretical bid: 56.354483166708235
# best bid: 56.6
# theoretical ask: 57.13771191951485
# best ask: 56.800000000000004
# - Inserting bid limit order in OB5X_202406_120C for 33 @    55.80.
# - Inserting ask limit order in OB5X_202406_120C for 33 @    56.90.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_100P
# theoretical bid: 24.64845673765507
# best bid: 24.5
# theoretical ask: 24.4337474685513
# best ask: 24.700000000000003
# - Inserting bid limit order in OB5X_202406_100P for 33 @    24.30.
# - Inserting ask limit order in OB5X_202406_100P for 33 @    24.80.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_100C
# theoretical bid: 64.75280730071437
# best bid: 64.7
# theoretical ask: 65.60025503039185
# best ask: 64.9
# - Inserting bid limit order in OB5X_202406_100C for 33 @    64.10.
# - Inserting ask limit order in OB5X_202406_100C for 33 @    65.30.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080C
# theoretical bid: 74.87002720119388
# best bid: 74.9
# theoretical ask: 75.78272361600514
# best ask: 75.2
# - Inserting bid limit order in OB5X_202406_080C for 33 @    74.30.
# - Inserting ask limit order in OB5X_202406_080C for 33 @    75.50.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080P
# theoretical bid: 14.989041168137373
# best bid: 14.700000000000001
# theoretical ask: 14.839580584358025
# best ask: 15.100000000000001
# - Inserting bid limit order in OB5X_202406_080P for 33 @    14.70.
# - Inserting ask limit order in OB5X_202406_080P for 33 @    15.10.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_120P
# theoretical bid: 35.93367707463764
# best bid: 35.9
# theoretical ask: 35.77049675294613
# best ask: 36.1
# - Inserting bid limit order in OB5X_202406_120P for 33 @    35.80.
# - Inserting ask limit order in OB5X_202406_120P for 33 @    36.30.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_120C
# theoretical bid: 56.61461913967704
# best bid: 56.6
# theoretical ask: 57.073633814184966
# best ask: 56.800000000000004
# - Inserting bid limit order in OB5X_202406_120C for 33 @    56.10.
# - Inserting ask limit order in OB5X_202406_120C for 33 @    56.80.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_100P
# theoretical bid: 24.576769355926768
# best bid: 24.6
# theoretical ask: 24.45117884465638
# best ask: 24.700000000000003
# - Inserting bid limit order in OB5X_202406_100P for 33 @    24.30.
# - Inserting ask limit order in OB5X_202406_100P for 33 @    24.70.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_100C
# theoretical bid: 65.03434434035215
# best bid: 64.60000000000001
# theoretical ask: 65.53094882810515
# best ask: 64.9
# - Inserting bid limit order in OB5X_202406_100C for 33 @    64.40.
# - Inserting ask limit order in OB5X_202406_100C for 33 @    65.20.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080C
# theoretical bid: 75.17332205527624
# best bid: 74.9
# theoretical ask: 75.70811035645464
# best ask: 75.2
# - Inserting bid limit order in OB5X_202406_080C for 33 @    74.60.
# - Inserting ask limit order in OB5X_202406_080C for 33 @    75.50.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080P
# theoretical bid: 14.939111522143758
# best bid: 14.8
# theoretical ask: 14.85170482428303
# best ask: 15.100000000000001
# - Inserting bid limit order in OB5X_202406_080P for 33 @    14.70.
# - Inserting ask limit order in OB5X_202406_080P for 33 @    15.10.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_120P
# theoretical bid: 35.887119894461286
# best bid: 35.800000000000004
# theoretical ask: 35.76958469463883
# best ask: 36.1
# - Inserting bid limit order in OB5X_202406_120P for 33 @    35.50.
# - Inserting ask limit order in OB5X_202406_120P for 33 @    35.90.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_120C
# theoretical bid: 56.74515830909556
# best bid: 56.6
# theoretical ask: 57.076169107277195
# best ask: 56.7
# - Inserting bid limit order in OB5X_202406_120C for 33 @    56.20.
# - Inserting ask limit order in OB5X_202406_120C for 33 @    56.80.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_100P
# theoretical bid: 24.54092648870126
# best bid: 24.6
# theoretical ask: 24.45047613438247
# best ask: 24.700000000000003
# - Inserting bid limit order in OB5X_202406_100P for 33 @    24.30.
# - Inserting ask limit order in OB5X_202406_100P for 33 @    24.70.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_100C
# theoretical bid: 65.17559785178938
# best bid: 64.60000000000001
# theoretical ask: 65.53369349605087
# best ask: 64.9
# - Inserting bid limit order in OB5X_202406_100C for 33 @    64.50.
# - Inserting ask limit order in OB5X_202406_100C for 33 @    65.20.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080C
# theoretical bid: 75.3254638815677
# best bid: 74.9
# theoretical ask: 75.7110681300745
# best ask: 75.0
# - Inserting bid limit order in OB5X_202406_080C for 33 @    74.80.
# - Inserting ask limit order in OB5X_202406_080C for 33 @    75.50.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080P
# theoretical bid: 14.914156818611517
# best bid: 14.9
# theoretical ask: 14.85121506775226
# best ask: 15.100000000000001
# - Inserting bid limit order in OB5X_202406_080P for 33 @    14.70.
# - Inserting ask limit order in OB5X_202406_080P for 33 @    15.10.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_120P
# theoretical bid: 36.01003516913175
# best bid: 35.9
# theoretical ask: 35.86682467556967
# best ask: 36.2
# - Inserting bid limit order in OB5X_202406_120P for 33 @    35.90.
# - Inserting ask limit order in OB5X_202406_120P for 33 @    36.40.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_120C
# theoretical bid: 56.40103288731069
# best bid: 56.5
# theoretical ask: 56.80213539074735
# best ask: 56.7
# - Inserting bid limit order in OB5X_202406_120C for 33 @    55.90.
# - Inserting ask limit order in OB5X_202406_120C for 33 @    56.60.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_100P
# theoretical bid: 24.635567604352662
# best bid: 24.5
# theoretical ask: 24.52530360957969
# best ask: 24.700000000000003
# - Inserting bid limit order in OB5X_202406_100P for 33 @    24.40.
# - Inserting ask limit order in OB5X_202406_100P for 33 @    24.80.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_100C
# theoretical bid: 64.80319842843943
# best bid: 64.60000000000001
# theoretical ask: 65.23724743268174
# best ask: 64.9
# - Inserting bid limit order in OB5X_202406_100C for 33 @    64.20.
# - Inserting ask limit order in OB5X_202406_100C for 33 @    64.90.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 37.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080C
# theoretical bid: 74.92432606145816
# best bid: 74.8
# theoretical ask: 75.39186098670669
# best ask: 75.0
# - Inserting bid limit order in OB5X_202406_080C for 33 @    74.40.
# - Inserting ask limit order in OB5X_202406_080C for 33 @    75.10.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 44.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080P
# theoretical bid: 14.98005946449463
# best bid: 14.9
# theoretical ask: 14.903281388841744
# best ask: 15.100000000000001
# - Inserting bid limit order in OB5X_202406_080P for 33 @    14.80.
# - Inserting ask limit order in OB5X_202406_080P for 33 @    15.10.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 35.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 44.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_120P
# theoretical bid: 35.96423232277375
# best bid: 36.0
# theoretical ask: 35.84624549255428
# best ask: 36.1
# - Inserting bid limit order in OB5X_202406_120P for 33 @    35.90.
# - Inserting ask limit order in OB5X_202406_120P for 33 @    36.30.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 44.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_120C
# theoretical bid: 56.528964326942976
# best bid: 56.5
# theoretical ask: 56.85996949507338
# best ask: 56.6
# - Inserting bid limit order in OB5X_202406_120C for 33 @    56.40.
# - Inserting ask limit order in OB5X_202406_120C for 33 @    57.00.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 44.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_100P
# theoretical bid: 24.600293160845617
# best bid: 24.5
# theoretical ask: 24.509463612927668
# best ask: 24.6
# - Inserting bid limit order in OB5X_202406_100P for 33 @    24.40.
# - Inserting ask limit order in OB5X_202406_100P for 33 @    24.80.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 44.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_100C
# theoretical bid: 64.94165841159003
# best bid: 64.60000000000001
# theoretical ask: 65.29982086207657
# best ask: 64.9
# - Inserting bid limit order in OB5X_202406_100C for 33 @    64.30.
# - Inserting ask limit order in OB5X_202406_100C for 33 @    64.90.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 44.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080C
# theoretical bid: 75.07349081451224
# best bid: 74.8
# theoretical ask: 75.45924923464648
# best ask: 75.0
# - Inserting bid limit order in OB5X_202406_080C for 33 @    74.50.
# - Inserting ask limit order in OB5X_202406_080C for 33 @    75.20.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 44.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080P
# theoretical bid: 14.955489637374317
# best bid: 14.9
# theoretical ask: 14.892256058183186
# best ask: 15.0
# - Inserting bid limit order in OB5X_202406_080P for 33 @    14.70.
# - Inserting ask limit order in OB5X_202406_080P for 33 @    15.10.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 53.
# - The current position in option OB5X_202406_080C is 44.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_120P
# theoretical bid: 36.140372686985614
# best bid: 36.0
# theoretical ask: 35.94073658491902
# best ask: 36.1
# - Inserting bid limit order in OB5X_202406_120P for 33 @    36.00.
# - Inserting ask limit order in OB5X_202406_120P for 33 @    36.50.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 47.
# - The current position in option OB5X_202406_080C is 44.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_120C
# theoretical bid: 56.03839197049652
# best bid: 56.5
# theoretical ask: 56.59468386515097
# best ask: 56.6
# - Inserting bid limit order in OB5X_202406_120C for 33 @    55.90.
# - Inserting ask limit order in OB5X_202406_120C for 33 @    56.70.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 47.
# - The current position in option OB5X_202406_080C is 44.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_100P
# theoretical bid: 24.73598000701616
# best bid: 24.400000000000002
# theoretical ask: 24.582200472669925
# best ask: 24.6
# - Inserting bid limit order in OB5X_202406_100P for 33 @    24.40.
# - Inserting ask limit order in OB5X_202406_100P for 33 @    24.90.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 47.
# - The current position in option OB5X_202406_080C is 44.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_100C
# theoretical bid: 64.41063267847323
# best bid: 64.7
# theoretical ask: 65.01278114334988
# best ask: 64.9
# - Inserting bid limit order in OB5X_202406_100C for 33 @    63.80.
# - Inserting ask limit order in OB5X_202406_100C for 33 @    64.70.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 14.
# - The current position in option OB5X_202406_080C is 44.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080C
# theoretical bid: 74.50131948370631
# best bid: 74.9
# theoretical ask: 75.15010623135365
# best ask: 75.0
# - Inserting bid limit order in OB5X_202406_080C for 33 @    74.00.
# - Inserting ask limit order in OB5X_202406_080C for 33 @    74.90.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 14.
# - The current position in option OB5X_202406_080C is 11.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_080P
# theoretical bid: 15.050030816242419
# best bid: 14.9
# theoretical ask: 14.94288956464932
# best ask: 15.100000000000001
# - Inserting bid limit order in OB5X_202406_080P for 33 @    14.80.
# - Inserting ask limit order in OB5X_202406_080P for 33 @    15.20.
# - The current position in option OB5X_202406_120P is -21.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 14.
# - The current position in option OB5X_202406_080C is 11.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -100
# option id: OB5X_202406_120P
# theoretical bid: 36.16895082057648
# best bid: 36.0
# theoretical ask: 36.05348819645207
# best ask: 36.1
# - Inserting bid limit order in OB5X_202406_120P for 33 @    36.10.
# - Inserting ask limit order in OB5X_202406_120P for 33 @    36.50.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is 2.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 14.
# - The current position in option OB5X_202406_080C is 11.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -52
# option id: OB5X_202406_120C
# theoretical bid: 55.95917041258695
# best bid: 56.5
# theoretical ask: 56.27977578630428
# best ask: 56.6
# - Inserting bid limit order in OB5X_202406_120C for 33 @    55.80.
# - Inserting ask limit order in OB5X_202406_120C for 33 @    56.40.
# - The current position in option OB5X_202406_120P is 12.
# - The current position in option OB5X_202406_120C is -31.
# - The current position in option OB5X_202406_100P is 3.
# - The current position in option OB5X_202406_100C is 14.
# - The current position in option OB5X_202406_080C is 11.
# - The current position in option OB5X_202406_080P is -2.
# stock position currently: -29
# option id: OB5X_202406_100P
# theoretical bid: 24.758004078906783
# best bid: 24.400000000000002
# theoretical ask: 24.669034911317283
# best ask: 24.900000000000002
# - Inserting bid limit order in OB5X_202406_100P for 33 @    24.50.
# - Inserting ask limit order in OB5X_202406_100P for 33 @    24.90.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 63
#      55 update_quotes(instrument_id=option_id,
#      56                 theoretical_price = mid_price + credit_calc(option_id, 10, 0.1),
#      57                 credit=price_diff/2 + 0.1,
#      58                 volume=33,
#      59                 position_limit=100,
#      60                 tick_size=0.10)
#      62 for i in range(1):
# ---> 63     hedge_delta_position(OB5X_ETF, get_midpoint_value(OB5X_ETF), futures=None, options=options, dual=None)
#      64     time.sleep(1)
#
# Cell In[36], line 26, in hedge_delta_position(stock_id, stock_value, futures, options, dual)
#      24 for option_id, option in options.items():
#      25     position = positions[option_id]
# ---> 26     current_delta = calculate_option_delta(option.expiry, option.strike, option.option_kind, stock_value, 0.03, 3.0)
#      27     current_delta = current_delta / 0.25
#      28     total_delta += current_delta * position
#
# Cell In[13], line 17, in calculate_option_delta(expiry_date, strike, option_kind, stock_value, interest_rate, volatility)
#      15     option_delta = call_delta(S=stock_value, K=strike, T=time_to_expiry, r=interest_rate, sigma=volatility)
#      16 elif option_kind == OptionKind.PUT:
# ---> 17     option_delta = put_delta(S=stock_value, K=strike, T=time_to_expiry, r=interest_rate, sigma=volatility)
#      18 else:
#      19     raise Exception(f"""Got unexpected value for option_kind argument, should be OptionKind.CALL or OptionKind.PUT but was {option_kind}.""")
#
# File ~/options_quoter/black_scholes.py:149, in put_delta(S, K, T, r, sigma)
#     119 def put_delta(S, K, T, r, sigma):
#     120     """
#     121     The delta, i.e. the first derivative of the option value with respect to the underlying,
#     122     of a put option paying max(K-S, 0) at expiry, under the Black-scholes model, for an option
#    (...)
#     146         The fair present value of the option.
#     147     """
# --> 149     return call_delta(S, K, T, r, sigma) - 1
#
# File ~/options_quoter/black_scholes.py:116, in call_delta(S, K, T, r, sigma)
#      86 def call_delta(S, K, T, r, sigma):
#      87     """
#      88     The delta, i.e. the first derivative of the option value with respect to the underlying,
#      89     of a call option paying max(S-K, 0) at expiry, under the Black-scholes model, for an option
#    (...)
#     113         The fair present value of the option.
#     114     """
# --> 116     return _norm_cdf(_d1(S, K, T, r, sigma))
#
# File ~/options_quoter/black_scholes.py:11, in _d1(S, K, T, r, sigma)
#      10 def _d1(S, K, T, r, sigma):
# ---> 11     return (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %%
NVDA_ID = "NVDA"
NVDA_DUAL = "NVDA_DUAL"
OB5X_ID = "OB5X"
OB5X_ETF = 'OB5X_ETF'

flag = True
i = 0
while True:
    OB5X_value_ask = get_OB5X_value('ask')
    OB5X_value_bid = get_OB5X_value('bid')
    futures = load_futures_for_underlying('OB5X')
    if (OB5X_value_ask is None or OB5X_value_bid is None):
        time.sleep(1)
        continue
    for future_id, future in futures.items():
        theoretical_value_bid = calculate_theoretical_future_value(underlying_value = OB5X_value_bid, expiry = future.expiry)
        theoretical_value_ask = calculate_theoretical_future_value(underlying_value = OB5X_value_ask, expiry = future.expiry)
        diff = theoretical_value_ask - theoretical_value_bid
        mid_price = theoretical_value_bid + diff/2
        
        #updating future quotes

        update_quotes(instrument_id = future_id,
                      theoretical_price = mid_price + credit_calc(future_id, 20, 0.1),
                      credit = diff/2 + 0.2,
                      volume = 20,
                      position_limit = 100,
                      tick_size = 0.10)
        
        time.sleep(1)
    
        for i in range(1):
            hedge_delta_position(OB5X_ETF, get_midpoint_value(OB5X_ETF), futures=futures, options=None, dual=None)
            time.sleep(1)


    # ---------------------------------------------------- NVDA --------------------------------------------------
    # NVDA options
    """
    options = load_instruments_for_underlying(NVDA_ID)
    futures = load_futures_for_underlying(NVDA_ID)
    for option_id, option in options.items():
        order_book = exchange.get_last_price_book(NVDA_ID)

        # check if order book is empty
        if(len(order_book.bids)==0 or len(order_book.asks)==0):
            continue

        theoretical_value_bid = calculate_theoretical_option_value(expiry=option.expiry,
                                                               strike=option.strike,
                                                               option_kind=option.option_kind,
                                                               stock_value=order_book.bids[0].price,
                                                               interest_rate=0.03,
                                                               volatility=3.0)

        theoretical_value_ask = calculate_theoretical_option_value(expiry=option.expiry,
                                                               strike=option.strike,
                                                               option_kind=option.option_kind,
                                                               stock_value=order_book.asks[0].price,
                                                               interest_rate=0.03,
                                                               volatility=3.0)

        if option.option_kind == OptionKind.CALL:
            price_diff = (theoretical_value_ask - theoretical_value_bid)
            mid_price = theoretical_value_bid + price_diff/2

        elif option.option_kind == OptionKind.PUT:
            price_diff = (theoretical_value_bid - theoretical_value_ask)
            mid_price = theoretical_value_ask + price_diff/2

        update_quotes(instrument_id=option_id,
                        theoretical_price = mid_price,
                        credit=price_diff/2+ 0.1,
                        volume=50,
                        position_limit=100,
                        tick_size=0.10)
    time.sleep(1.0)
    
    # hedge all NVDA positions
    hedge_delta_position(NVDA_ID, get_midpoint_value(NVDA_ID), futures=futures, options=options, dual=NVDA_DUAL)

    # NVDA futures
    
    for future_id,future in futures.items():
        order_book = exchange.get_last_price_book(NVDA_ID)

        # check if order book is empty
        if(len(order_book.bids)==0 or len(order_book.asks)==0):
            continue
        theoretical_value_bid = calculate_theoretical_future_value(underlying_value=order_book.bids[0].price, expiry=future.expiry)
        theoretical_value_ask = calculate_theoretical_future_value(underlying_value=order_book.asks[0].price, expiry=future.expiry)
        diff = theoretical_value_ask-theoretical_value_bid
        mid_price = theoretical_value_bid+diff/2

        update_quotes(instrument_id=future_id,
                        theoretical_price = mid_price,
                        credit=diff/2 + 0.1,
                        volume=50,
                        position_limit=100,
                        tick_size=0.10)

    # NVDA_DUAL
    order_book = exchange.get_last_price_book(NVDA_ID)
    bid_price = order_book.bids[0].price
    ask_price = order_book.asks[0].price

    mid_point = (ask_price + bid_price)/2
    creditdual = (ask_price - bid_price)/2 + 0.20
    update_quotes(instrument_id=NVDA_DUAL,
                theoretical_price = mid_point,
                credit = creditdual,
                volume = 20,
                position_limit = 100,
                tick_size = 0.10)
    time.sleep(1.0)

    hedge_delta_position(NVDA_ID, get_midpoint_value(NVDA_ID), futures=futures, options=options, dual=NVDA_DUAL)
      """
# Out:
# Instrument(instrument_id=OB5X_202412_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-12-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.374979
# 139.900139
# theoretical value bid at: 143.61309210393406
# OB5X_202412_F best bid at: 143.3
# theoretical value ask at: 144.1005343691149
# OB5X_202412_F best ask at: 143.8
# - Inserting bid limit order in OB5X_202412_F for 20 @   143.40.
# - Inserting ask limit order in OB5X_202412_F for 20 @   144.40.
# stock position currently: 20
# Instrument(instrument_id=OB5X_202409_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-09-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.374979
# 139.900139
# theoretical value bid at: 142.54295160794283
# OB5X_202409_F best bid at: 142.5
# theoretical value ask at: 143.02676167149414
# OB5X_202409_F best ask at: 142.70000000000002
# - Inserting bid limit order in OB5X_202409_F for 20 @   142.40.
# - Inserting ask limit order in OB5X_202409_F for 20 @   143.40.
# stock position currently: 10
# Instrument(instrument_id=OB5X_202406_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-06-21 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.374979
# 139.900139
# theoretical value bid at: 141.48078532113772
# OB5X_202406_F best bid at: 141.0
# theoretical value ask at: 141.96099024860254
# OB5X_202406_F best ask at: 141.8
# - Inserting bid limit order in OB5X_202406_F for 20 @   141.20.
# - Inserting ask limit order in OB5X_202406_F for 20 @   142.20.
# Instrument(instrument_id=OB5X_202412_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-12-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 139.90306399999997
# 139.46699600000002
# theoretical value bid at: 143.16845263593075
# OB5X_202412_F best bid at: 143.0
# theoretical value ask at: 143.6160938886552
# OB5X_202412_F best ask at: 143.4
# - Inserting bid limit order in OB5X_202412_F for 20 @   142.80.
# - Inserting ask limit order in OB5X_202412_F for 20 @   143.80.
# stock position currently: -20
# Instrument(instrument_id=OB5X_202409_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-09-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 139.90306399999997
# 139.46699600000002
# theoretical value bid at: 142.101625398026
# OB5X_202409_F best bid at: 141.9
# theoretical value ask at: 142.54593102845192
# OB5X_202409_F best ask at: 142.3
# - Inserting bid limit order in OB5X_202409_F for 20 @   141.90.
# - Inserting ask limit order in OB5X_202409_F for 20 @   142.80.
# Instrument(instrument_id=OB5X_202406_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-06-21 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 139.90306399999997
# 139.46699600000002
# theoretical value bid at: 141.04274768131626
# OB5X_202406_F best bid at: 141.5
# theoretical value ask at: 141.48374254503685
# OB5X_202406_F best ask at: 141.70000000000002
# - Inserting bid limit order in OB5X_202406_F for 20 @   140.70.
# - Inserting ask limit order in OB5X_202406_F for 20 @   141.60.
# stock position currently: 0
# Instrument(instrument_id=OB5X_202412_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-12-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.041051
# 139.501253
# theoretical value bid at: 143.20361798981423
# OB5X_202412_F best bid at: 143.0
# theoretical value ask at: 143.7577422354427
# OB5X_202412_F best ask at: 143.4
# - Inserting bid limit order in OB5X_202412_F for 20 @   143.00.
# - Inserting ask limit order in OB5X_202412_F for 20 @   144.00.
# stock position currently: 20
# Instrument(instrument_id=OB5X_202409_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-09-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.041051
# 139.501253
# theoretical value bid at: 142.1365287170794
# OB5X_202409_F best bid at: 141.9
# theoretical value ask at: 142.68652387680828
# OB5X_202409_F best ask at: 142.4
# - Inserting bid limit order in OB5X_202409_F for 20 @   142.00.
# - Inserting ask limit order in OB5X_202409_F for 20 @   143.00.
# Instrument(instrument_id=OB5X_202406_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-06-21 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.041051
# 139.501253
# theoretical value bid at: 141.0773909164138
# OB5X_202406_F best bid at: 141.8
# theoretical value ask at: 141.62328775836303
# OB5X_202406_F best ask at: 142.20000000000002
# - Inserting bid limit order in OB5X_202406_F for 20 @   140.80.
# - Inserting ask limit order in OB5X_202406_F for 20 @   141.90.
# stock position currently: 80
# Instrument(instrument_id=OB5X_202412_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-12-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.077159
# 139.53736100000003
# theoretical value bid at: 143.2406834703002
# OB5X_202412_F best bid at: 144.0
# theoretical value ask at: 143.79480771273145
# OB5X_202412_F best ask at: 144.4
# - Inserting bid limit order in OB5X_202412_F for 20 @   143.10.
# - Inserting ask limit order in OB5X_202412_F for 20 @   144.10.
# Instrument(instrument_id=OB5X_202409_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-09-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.077159
# 139.53736100000003
# theoretical value bid at: 142.17331800272535
# OB5X_202409_F best bid at: 142.20000000000002
# theoretical value ask at: 142.72331315925427
# OB5X_202409_F best ask at: 142.70000000000002
# - Inserting bid limit order in OB5X_202409_F for 20 @   142.10.
# - Inserting ask limit order in OB5X_202409_F for 20 @   143.20.
# Instrument(instrument_id=OB5X_202406_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-06-21 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.077159
# 139.53736100000003
# theoretical value bid at: 141.1139060638452
# OB5X_202406_F best bid at: 140.9
# theoretical value ask at: 141.65980290264534
# OB5X_202406_F best ask at: 142.20000000000002
# - Inserting bid limit order in OB5X_202406_F for 20 @   141.00.
# - Inserting ask limit order in OB5X_202406_F for 20 @   142.00.
# Instrument(instrument_id=OB5X_202412_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-12-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.351881
# 139.691274
# theoretical value bid at: 143.3986804961586
# OB5X_202412_F best bid at: 143.6
# theoretical value ask at: 144.07682000633127
# OB5X_202412_F best ask at: 144.1
# - Inserting bid limit order in OB5X_202412_F for 20 @   143.10.
# - Inserting ask limit order in OB5X_202412_F for 20 @   144.30.
# stock position currently: 60
# Instrument(instrument_id=OB5X_202409_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-09-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.351881
# 139.691274
# theoretical value bid at: 142.3301377024878
# OB5X_202409_F best bid at: 142.6
# theoretical value ask at: 143.00322402050782
# OB5X_202409_F best ask at: 142.8
# - Inserting bid limit order in OB5X_202409_F for 20 @   142.30.
# - Inserting ask limit order in OB5X_202409_F for 20 @   143.50.
# Instrument(instrument_id=OB5X_202406_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-06-21 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.351881
# 139.691274
# theoretical value bid at: 141.26955720508863
# OB5X_202406_F best bid at: 141.3
# theoretical value ask at: 141.93762798505273
# OB5X_202406_F best ask at: 141.70000000000002
# - Inserting bid limit order in OB5X_202406_F for 20 @   141.10.
# - Inserting ask limit order in OB5X_202406_F for 20 @   142.30.
# Instrument(instrument_id=OB5X_202412_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-12-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 139.985286
# 139.53673999999998
# theoretical value bid at: 143.24004432736575
# OB5X_202412_F best bid at: 143.5
# theoretical value ask at: 143.7004947357803
# OB5X_202412_F best ask at: 144.0
# - Inserting bid limit order in OB5X_202412_F for 20 @   143.00.
# - Inserting ask limit order in OB5X_202412_F for 20 @   144.00.
# Instrument(instrument_id=OB5X_202409_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-09-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 139.985286
# 139.53673999999998
# theoretical value bid at: 142.1726836222185
# OB5X_202409_F best bid at: 142.6
# theoretical value ask at: 142.62970296025557
# OB5X_202409_F best ask at: 142.9
# - Inserting bid limit order in OB5X_202409_F for 20 @   142.10.
# - Inserting ask limit order in OB5X_202409_F for 20 @   143.10.
# Instrument(instrument_id=OB5X_202406_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-06-21 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 139.985286
# 139.53673999999998
# theoretical value bid at: 141.11327641165434
# OB5X_202406_F best bid at: 141.3
# theoretical value ask at: 141.56689024612078
# OB5X_202406_F best ask at: 141.4
# - Inserting bid limit order in OB5X_202406_F for 20 @   141.00.
# - Inserting ask limit order in OB5X_202406_F for 20 @   141.90.
# Instrument(instrument_id=OB5X_202412_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-12-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.34798700000002
# 139.886071
# theoretical value bid at: 143.5986457435644
# OB5X_202412_F best bid at: 143.4
# theoretical value ask at: 144.07282098897866
# OB5X_202412_F best ask at: 143.6
# - Inserting bid limit order in OB5X_202412_F for 20 @   143.30.
# - Inserting ask limit order in OB5X_202412_F for 20 @   144.30.
# Instrument(instrument_id=OB5X_202409_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-09-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.34798700000002
# 139.886071
# theoretical value bid at: 142.528612900801
# OB5X_202409_F best bid at: 142.20000000000002
# theoretical value ask at: 142.9992548044941
# OB5X_202409_F best ask at: 142.6
# - Inserting bid limit order in OB5X_202409_F for 20 @   142.50.
# - Inserting ask limit order in OB5X_202409_F for 20 @   143.40.
# stock position currently: 40
# Instrument(instrument_id=OB5X_202406_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-06-21 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.34798700000002
# 139.886071
# theoretical value bid at: 141.46655346287326
# OB5X_202406_F best bid at: 141.1
# theoretical value ask at: 141.93368835372462
# OB5X_202406_F best ask at: 141.3
# - Inserting bid limit order in OB5X_202406_F for 20 @   141.30.
# - Inserting ask limit order in OB5X_202406_F for 20 @   142.30.
# Instrument(instrument_id=OB5X_202412_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-12-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 139.850584
# 139.389114
# theoretical value bid at: 143.08849868447456
# OB5X_202412_F best bid at: 143.1
# theoretical value ask at: 143.56221609031812
# OB5X_202412_F best ask at: 143.20000000000002
# - Inserting bid limit order in OB5X_202412_F for 20 @   142.70.
# - Inserting ask limit order in OB5X_202412_F for 20 @   143.70.
# stock position currently: 0
# Instrument(instrument_id=OB5X_202409_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-09-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 139.850584
# 139.389114
# theoretical value bid at: 142.0222672296089
# OB5X_202409_F best bid at: 142.70000000000002
# theoretical value ask at: 142.49245470535035
# OB5X_202409_F best ask at: 143.20000000000002
# - Inserting bid limit order in OB5X_202409_F for 20 @   141.90.
# - Inserting ask limit order in OB5X_202409_F for 20 @   142.80.
# stock position currently: 1
# Instrument(instrument_id=OB5X_202406_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-06-21 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 139.850584
# 139.389114
# theoretical value bid at: 140.96398085358553
# OB5X_202406_F best bid at: 141.5
# theoretical value ask at: 141.43066470268033
# OB5X_202406_F best ask at: 141.6
# - Inserting bid limit order in OB5X_202406_F for 20 @   140.70.
# - Inserting ask limit order in OB5X_202406_F for 20 @   141.70.
# Instrument(instrument_id=OB5X_202412_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-12-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.11964
# 139.683572
# theoretical value bid at: 143.39077076781942
# OB5X_202412_F best bid at: 143.1
# theoretical value ask at: 143.8384120024395
# OB5X_202412_F best ask at: 143.5
# - Inserting bid limit order in OB5X_202412_F for 20 @   143.00.
# - Inserting ask limit order in OB5X_202412_F for 20 @   144.00.
# Instrument(instrument_id=OB5X_202409_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-09-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.11964
# 139.683572
# theoretical value bid at: 142.3222869162489
# OB5X_202409_F best bid at: 142.3
# theoretical value ask at: 142.7665925287041
# OB5X_202409_F best ask at: 142.4
# - Inserting bid limit order in OB5X_202409_F for 20 @   142.20.
# - Inserting ask limit order in OB5X_202409_F for 20 @   143.10.
# stock position currently: 51
# Instrument(instrument_id=OB5X_202406_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-06-21 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)
# 140.11964
# 139.683572
# theoretical value bid at: 141.26176492610608
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 22
#      20 print(f"theoretical value bid at: {theoretical_value_bid}")
#      21 order_book_future = exchange.get_last_price_book(future_id)
# ---> 22 print(f"{future_id} best bid at: {order_book_future.bids[0].price}")
#      23 theoretical_value_ask = calculate_theoretical_future_value(underlying_value = OB5X_value_ask, expiry = future.expiry)
#      24 print(f"theoretical value ask at: {theoretical_value_ask}")
#
# IndexError: list index out of range

# %%
OB5X_ID = 'OB5X'

futures = load_futures_for_underlying(OB5X_ID)
print(futures)

for future in futures:
    print(calculate_theoretical_future_value(get_OB5X_value('ask'), futures[future].expiry))
    print(calculate_theoretical_future_value(get_OB5X_value('bid'), futures[future].expiry))

print(exchange.get_last_price_book('OB5X_202412_F'))
print(exchange.get_last_price_book('OB5X_202406_F'))
print(exchange.get_last_price_book('OB5X_202409_F'))
# Out:
# {'OB5X_202412_F': Instrument(instrument_id=OB5X_202412_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-12-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False), 'OB5X_202409_F': Instrument(instrument_id=OB5X_202409_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-09-20 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False), 'OB5X_202406_F': Instrument(instrument_id=OB5X_202406_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.INDEX_FUTURE, expiry=2024-06-21 12:00:00, interest_rate=0.03, index_id=OB5X, instrument_group=OB5X, paused=False, expired=False)}
# 145.7650937668278
# 145.22423589292072
# 144.67891780084238
# 144.14209015673086
# 143.6008355299868
# 143.06800808420712
# PriceBook(OB5X_202412_F 2024-02-05 19:01:46.898563)
#  #bids | price | #asks
#        | 145.9 |   33
#        | 144.7 |   30
#        | 144.6 |  150
#    40  | 144.3 |
#   100  | 144.2 |
#   160  | 144.1 |
# PriceBook(OB5X_202406_F 2024-02-05 19:01:46.049334)
#  #bids | price | #asks
#        | 143.8 |  183
#        | 142.6 |   8
#   100  | 142.1 |
# PriceBook(OB5X_202409_F 2024-02-05 19:01:47.066714)
#  #bids | price | #asks
#        | 144.8 |   23
#        | 143.6 |  150
#    40  | 143.5 |
#   100  | 143.2 |
#   150  | 143.1 |

# %%
len(order_book.bids)==0
# Out:
# False

# %%
for future_id,future in futures.items():
    print(exchange.get_outstanding_orders(future_id))
# Out:
# {93717909: OrderStatus(order_id=93717909, instrument_id=NVDA_202412_F, price=75.0, volume=100, side=bid), 93717910: OrderStatus(order_id=93717910, instrument_id=NVDA_202412_F, price=75.5, volume=50, side=ask)}
# {93717930: OrderStatus(order_id=93717930, instrument_id=NVDA_202406_F, price=73.9, volume=100, side=bid)}
# {93717940: OrderStatus(order_id=93717940, instrument_id=NVDA_202409_F, price=74.4, volume=100, side=bid)}

# %%
NVDA_ID = "NVDA"
futures = load_futures_for_underlying(NVDA_ID)
print(futures)
ask_NVDA = exchange.get_last_price_book(NVDA_ID).asks[0].price
bid_NVDA = exchange.get_last_price_book(NVDA_ID).bids[0].price
for future in futures:
    print(calculate_theoretical_future_value(ask_NVDA, futures[future].expiry))
    print(calculate_theoretical_future_value(bid_NVDA, futures[future].expiry))

print(exchange.get_last_price_book('NVDA_202412_F'))
print(exchange.get_last_price_book('NVDA_202406_F'))
print(exchange.get_last_price_book('NVDA_202409_F'))
# Out:
# {'NVDA_202412_F': Instrument(instrument_id=NVDA_202412_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.STOCK_FUTURE, base_instrument_id=NVDA, expiry=2024-12-20 12:00:00, interest_rate=0.03, instrument_group=NVDA, paused=False, expired=False), 'NVDA_202406_F': Instrument(instrument_id=NVDA_202406_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.STOCK_FUTURE, base_instrument_id=NVDA, expiry=2024-06-21 12:00:00, interest_rate=0.03, instrument_group=NVDA, paused=False, expired=False), 'NVDA_202409_F': Instrument(instrument_id=NVDA_202409_F, tick_size=0.1, price_change_limit=PriceChangeLimit(absolute_change=5.0000, relative_change=10.00%), instrument_type=InstrumentType.STOCK_FUTURE, base_instrument_id=NVDA, expiry=2024-09-20 12:00:00, interest_rate=0.03, instrument_group=NVDA, paused=False, expired=False)}
# 71.24762645862033
# 71.04230188669197
# 70.18977194466979
# 69.98749594482884
# 70.71672116783502
# 70.51292658233653
# PriceBook(NVDA_202412_F 2024-02-04 19:48:19.408780)
#  #bids | price | #asks
#        |  71.2 |  150
#        |  71.1 |   50
#   150  |  70.7 |
#   100  |  70.6 |
# PriceBook(NVDA_202406_F 2024-02-04 19:48:19.592155)
#  #bids | price | #asks
#        |  70.1 |  100
#        |  70.0 |  100
#   150  |  69.6 |
#   100  |  69.5 |
# PriceBook(NVDA_202409_F 2024-02-04 19:48:19.807209)
#  #bids | price | #asks
#        |  70.7 |  150
#        |  70.6 |  100
#   117  |  70.2 |
#   100  |  70.1 |
